# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
titanic = pd.read_csv('train.csv', usecols = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 
                                             'Fare', 'Embarked'])
titanic.dropna(inplace = True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    object
#  3   Age       712 non-null    float64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    float64
#  7   Embarked  712 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 50.1+ KB

# %%
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
sns.distplot(titanic.Fare)
plt.show()

# %%
sns.distplot(titanic.Age)
plt.show()

# %%
sns.kdeplot(titanic.Age, shade=True)
#plt.grid()
#sns.set_style('darkgrid')
#sns.set_style('whitegrid')
#sns.set_style('dark')
sns.set_style('white') #Will apply future plots
#sns.set_style('ticks')
sns.despine(left = True, bottom = True) #Default apply to top and right
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# devtmpfs        3.9G     0  3.9G   0% /dev
# tmpfs           3.9G  157M  3.7G   4% /dev/shm
# tmpfs           3.9G   10M  3.9G   1% /run
# tmpfs           3.9G     0  3.9G   0% /sys/fs/cgroup
# /dev/nvme0n1p6   89G   27G   62G  30% /
# /dev/nvme0n1p1  256M   34M  223M  13% /boot/efi
# /dev/nvme0n1p6   89G   27G   62G  30% /home
# /dev/nvme0n1p6   89G   27G   62G  30% /root
# /dev/nvme0n1p6   89G   27G   62G  30% /srv
# /dev/nvme0n1p6   89G   27G   62G  30% /.snapshots
# /dev/nvme0n1p6   89G   27G   62G  30% /usr/local
# /dev/nvme0n1p6   89G   27G   62G  30% /boot/grub2/x86_64-efi
# /dev/nvme0n1p6   89G   27G   62G  30% /opt
# /dev/nvme0n1p6   89G   27G   62G  30% /tmp
# /dev/nvme0n1p6   89G   27G   62G  30% /boot/grub2/i386-pc
# /dev/nvme0n1p6   89G   27G   62G  30% /var
# tmpfs           783M   24K  783M   1% /run/user/463
# tmpfs           783M  4.6M  779M   1% /run/user/1000

# %%
# Condition on unique values of the 'Survived' column
g = sns.FacetGrid(titanic, col = 'Survived', height = 6)
# The seaborn.FacetGrid object is used to represent the layout of the plots in the grid and the column used 
# for subsetting the data.
# For each subset of values, generate a kernel density plot of the 'Age' columns
g.map(sns.kdeplot, 'Age', shade = True)

# %%
g = sns.FacetGrid(titanic, col = 'Survived', height= 6) #Facet another workd for subset
g.map(plt.hist, 'Age')

# %%
g = sns.FacetGrid(titanic, col = 'Pclass', height = 6)
g.map(sns.kdeplot, 'Age', shade = True)
sns.despine(left = 'off', bottom = 'off')
plt.show()

# %%
g = sns.FacetGrid(titanic, col = 'Survived', row = 'Pclass', hue = 'Sex', height = 3)
g.map(sns.kdeplot, 'Age', shade = True)
g.add_legend()
sns.despine(left = 'off', bottom = 'off')
plt.show()
